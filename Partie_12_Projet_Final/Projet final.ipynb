# %% [markdown]
# # Projet Final
# ## Liste des projets
#
# Pour le projet final, nous vous proposons une liste de problèmes à résoudre !
#
# Cette liste contient environ 100 idées de projets à essayer en Python ! Certains d'entre eux sont simples et nous avons déjà abordé certains avant.
#
# Choisissez un projet simple que vous pensez que vous pouvez finir dans une journée pour commencer, puis vous pourrez revenir en choisir un autre pour lequel vous pensez qu'il pourrait vous prendre plus d'une semaine et de longues recherches sur le Web !
#
# Il y a quelques exemples de solutions dans le dossier aussi n'hésitez pas à les explorer et surout à vous rappeler:
#
# De bien vous AMUSER !

# %% [markdown]
# ## Nombres
#
# **Trouver PI au Nième décimale** - Saisissez un nombre et faites en sorte que le programme génère PI jusqu'à plusieurs décimales. Pensez à donner une limite à ce que doit calculer le programme.
#
# **Trouver e au Nième décimale** - Tout comme le problème précédent, mais avec e au lieu de PI. Entrez un nombre et faites en sorte que le programme génère e jusqu'à plusieurs décimales. Pensez à donner une limite à ce que doit calculer le programme.
#
# **Séquence Fibonacci** - Entrez un nombre et faites en sorte que le programme génère la séquence Fibonacci à ce nombre ou au Nième nombre.
#
# Prime Factorization - Demandez à l'utilisateur d'entrer un numéro et de trouver tous les Prime Factors (s'il y en a) et de les afficher.
#
# Next Prime Number - Demandez au programme de trouver les nombres premiers jusqu'à ce que l'utilisateur décide de cesser de demander le suivant.
#
# Calculer le coût total de carrelage qu'il faudrait pour couvrir un plan d'étage de largeur et de hauteur, en utilisant un coût saisi par l'utilisateur.
#
# Calculatrice hypothécaire - Calculez les paiements mensuels d'un prêt hypothécaire à durée déterminée sur des N-termes donnés à un taux d'intérêt donné. Également comprendre combien de temps il faudra à l'utilisateur de rembourser le prêt. Pour ajouter de la complexité, ajoutez une option pour les utilisateurs de sélectionner l'intervalle de composition (mensuel, hebdomadaire, quotidien, continuellement).
#
# Change Return Program - L'utilisateur inscrit un coût, puis le montant d'argent donné. Le programme permettra de déterminer le changement et le nombre de trimestres, les dimes, nickels, pièces de monnaie nécessaire pour le changement.
#
# Convertisseur binaire / décimal - Développez un convertisseur pour convertir un nombre décimal en nombre binaire ou un nombre binaire en son équivalent décimal.
#
# Calculatrice - Une calculatrice simple pour faire des opérateurs de base. Faire une calculatrice scientifique pour plus de complexité.
#
# Convertisseur d'unités (temp, monnaie, volume, masse et plus) - Convertit plusieurs unités entre elles. L'utilisateur saisit le type d'unité en cours de saisie, le type d'unité auquel il veut convertir et la valeur. Le programme effectuera alors la conversion.
#
# Réveil - Une horloge simple où il joue un son après X nombre de minutes / secondes ou à un moment particulier.
#
# Distance entre deux villes - Calcule la distance entre deux villes et permet à l'utilisateur de spécifier une unité de distance. Ce programme peut nécessiter de trouver des coordonnées pour les villes comme la latitude et la longitude.
#
# Validateur de carte de crédit - prend un numéro de carte de crédit auprès d'un fournisseur de carte de crédit commun (Visa, MasterCard, American Express, Discoverer) et le valide pour s'assurer qu'il s'agit d'un numéro valide (voir comment les cartes de crédit utilisent une somme de contrôle).
#
# Calculateur d'impôt - Demande à l'utilisateur de saisir un coût et une taxe nationale ou nationale. Il retourne ensuite la taxe plus le coût total avec la taxe.
#
# Le facteur d'un entier positif, n, est défini comme le produit de la suite n, n-1, n-2, ... 1 et le factoriel de zéro, 0, est défini comme étant 1. Résoudre ceci En utilisant les deux boucles et la récursivité.
#
# Complex Number Algebra - Montrer l'addition, la multiplication, la négation et l'inversion de nombres complexes dans des fonctions distinctes. (Les opérations de soustraction et de division peuvent être effectuées avec des paires de ces opérations.) Imprimer les résultats pour chaque opération testée.
#
# Happy Numbers - Un nombre heureux est défini par le processus suivant. En commençant par n'importe quel entier positif, remplacer le nombre par la somme des carrés de ses chiffres, et répéter le processus jusqu'à ce que le nombre soit égal à 1 (où il restera), ou il boucles sans fin dans un cycle qui ne comprend pas 1. Ces nombres Pour lequel ce processus se termine en 1 sont des nombres heureux, tandis que ceux qui ne finissent pas en 1 sont des nombres malheureux. Affichez ici un exemple de votre sortie. Trouvez les 8 premiers nombres heureux.
#
# Noms de numéros - Montre comment épeler un nombre en anglais. Vous pouvez utiliser une implémentation préexistante ou lancer la vôtre, mais vous devez prendre en charge les entrées d'au moins un million (ou la valeur maximale du type entier borné par défaut de votre langue, si moins). Facultatif: Prise en charge des entrées autres que des entiers positifs (comme zéro, nombres entiers négatifs et nombres à virgule flottante).
#
# Coin Flip Simulation - Ecrire un code qui simule renverser une seule pièce de monnaie, mais de nombreuses fois l'utilisateur décide. Le code doit enregistrer les résultats et compter le nombre de queues et de têtes.
#
# Limit Calculator (Calculateur de limite) - Demandez à l'utilisateur d'entrer f (x) et la valeur limite, puis retournez la valeur de l'instruction de limite. Facultatif: Rendez la calculatrice capable de supporter des limites infinies.
#
# Exponentiation rapide - Demandez à l'utilisateur d'entrer 2 entiers a et b et de fournir a ^ b (c'est-à-dire pow (a, b)) dans O (lg n) la complexité du temps.

# %% [markdown]
# ## Algorithmes classiques
#
# **Conjecture de Collatz** - Commencez par un nombre n> 1. Trouvez le nombre de pas qu'il faut pour atteindre un en utilisant le processus suivant: Si n est pair, divisez-le par 2. Si n est impair, multipliez-le par 3 et ajoutez 1.
#
# **Sorting** - Implémentez deux types d'algorithmes de tri: Merge sort et bubble sort.
#
# **Closest pair problem** - Le plus proche paire de points problème ou problème de paire la plus proche est un problème de géométrie computationnelle: donné n points dans l'espace métrique, trouver une paire de points avec la plus petite distance entre eux.
#
# **Sieve d'Eratosthènes** - Le tamis de Eratosthènes est l'un des moyens les plus efficaces pour trouver tous les primes plus petits (moins de 10 millions ou plus).

# %% [markdown]
# ## Graph
#
# **Graph de liens** - Créer un programme qui va créer un graphe ou un réseau à partir d'une série de liens.
#
# **Eulerian Path** - Créer un programme qui Prendra comme entrée un graphe et sortira soit un chemin Eulérien, soit un cycle Eulérien, soit déclarera qu'il n'est pas possible. Un chemin Eulerian commence à un noeud et parcourt chaque bord d'un graphe à travers chaque noeud et finit à un autre noeud. Un cycle eulérien est un chemin eulérien qui démarre et se termine au même nœud.
#
# **Connected Graph** - Crée un programme qui prend un graphe comme entrée et sort si chaque nœud est connecté ou non.
#
# **Dijkstra's Algorithm - Créer un programme qui trouve le chemin le plus court.
#
# **Minimum Spanning Tree** - Créer un programme qui prend un graphe connecté et non dirigé avec des poids et des sorties de l'arborescence minimale du graphe c'est-à-dire, un sous-graphe qui est un arbre, contient tous les sommets et la somme de Ses poids est le moins possible.

# %% [markdown]
# ## Structures de données
#
# **Index inversé** - Un index inversé est une structure de données utilisée pour créer une recherche de texte intégral. Étant donné un ensemble de fichiers texte, implémentez un programme pour créer un index inversé. Créez également une interface utilisateur pour effectuer une recherche à l'aide de cet index inversé qui renvoie une liste de fichiers contenant le terme / les termes de la requête. L'index de recherche peut être dans memory.

# %% [markdown]
# ## Text
#
# **Fizz Buzz** - Écrire un programme qui imprime les numéros de 1 à 100. Mais pour les multiples de trois imprimer "Fizz" au lieu du nombre et pour les multiples de cinq imprimer "Buzz". Pour les nombres qui sont des multiples de trois et cinq d'impression "FizzBuzz".
#
# **Inverser une chaîne** - Entrer une chaîne et le programme va l'inverser et l'imprimer.
#
# **Pig Latin** - Pig Latin est un jeu d'altérations jouées sur le jeu en langue anglaise. Pour créer la forme latine du porc d'un mot anglais, le son consonantique initial est transposé à la fin du mot et un ay est apposé (Ex: "banane" donnerait anana-bay). Lisez Wikipedia pour plus d'informations sur les règles.
#
# **Comptez les voyelles** - Entrez une chaîne et le programme compte le nombre de voyelles dans le texte. Pour plus de complexité, il doit déclarer une somme de chaque voyelle trouvée.
#
# **Vérifier si Palindrome** - Vérifie si la chaîne saisie par l'utilisateur est un palindrome. C'est-à-dire qu'il lit les mêmes en avant que vers l'arrière comme «racecar»
#
# **Compter les mots dans une chaîne** - Compte le nombre de mots individuels dans une chaîne. Pour plus de complexité lire ces chaînes à partir d'un fichier texte et générer un summary.
#
# **Text Editor** - application de style Notepad qui peut ouvrir, modifier et enregistrer des documents texte. Facultatif: Ajouter la mise en surbrillance de la syntaxe et d'autres fonctionnalités.
#
# **RSS Feed Creator** - Compte tenu d'un lien vers RSS / Atom Feed, obtenir tous les messages et les afficher.
#
# **Quote Tracker (symboles de bourse etc)** - Un programme qui peut sortir et vérifier la valeur actuelle des stocks Pour une liste de symboles saisis par l'utilisateur. L'utilisateur peut définir la fréquence de vérification des stocks. Pour CLI, indiquez si le stock a augmenté ou diminué. Facultatif: Si l'interface utilisateur graphique, le programme peut afficher vert vers le haut et rouge vers le bas des flèches pour montrer quelle direction la valeur de la valeur a déplacé.
#
# **Guestbook / Journal** - une application simple qui permet aux gens d'ajouter des commentaires ou écrire des écritures de journal. Il peut autoriser des commentaires ou non et des horodatages pour toutes les entrées. Peut également être transformé en boîte de crier. Facultatif: Déployez-le sur Google App Engine ou Heroku ou tout autre PaaS (si possible, bien sûr).
#
# **Vigenere / Vernam / Ceasar Ciphers** - Fonctions pour crypter et déchiffrer des messages de données. Ensuite, envoyez-les à un ami.
#
# **Regex Query Tool** - Un outil qui permet à l'utilisateur d'entrer une chaîne de texte, puis dans un contrôle séparé entrer un motif regex. Il exécutera l'expression régulière contre le texte source et renverra toutes les correspondances ou les erreurs de drapeau dans l'expression régulière.

# %% [markdown]
# ## Networking
#
# **FTP Program** - Un programme de transfert de fichiers qui peut transférer des fichiers d'avant en arrière à partir d'une web sépare séparément.
#
# **Bandwidth Monitor** - Suit la quantité de données que vous avez téléchargées et téléchargées depuis le réseau au cours de votre session en ligne. Voyez si vous pouvez savoir quelles périodes de la journée que vous utilisez de plus en plus et de générer un rapport ou un graphique qui montre it.
#
# **Port Scanner** - Entrez une adresse IP et une plage de ports où le programme va alors tenter de trouver des ports ouverts sur le donné Ordinateur en se connectant à chacun d'eux. Lors de toutes les connexions réussies marquer le port comme open.
#
# **Mail Checker (POP3 / IMAP)** - L'utilisateur saisit diverses informations de compte comprennent le serveur web et IP, type de protocole (POP3 ou IMAP) et l'application va vérifier pour e-mail à un intervAl.
#
# **Country from IP Lookup** - Entrez une adresse IP et trouvez le pays dans lequel l'adresse IP est enregistrée. Facultatif: Recherchez l'Ip automatiquement. Outil de recherche Whois - Entrez une adresse IP ou hôte et demandez-lui de le consulter par whois et de retourner les résultats À vous.
#
# **Site Checker avec Time Scheduling** - Une application qui tente de se connecter à un site Web ou un serveur toutes les minutes ou un certain temps et vérifier si elle est en place. S'il est en panne, il vous en informera par courriel ou en affichant un avis à l'écran.
#
# **ClassesProduct Inventory Project** - Créez une application qui gère un inventaire des produits. Créez une classe de produit qui a un prix, un ID et une quantité en main. Ensuite, créez une classe d'inventaire qui conserve la trace de divers produits et peut résumer la valeur de stock.
#
# **Airline / Hotel Reservation System** - Créer un système de réservation qui livre des sièges d'avion ou des chambres d'hôtel. Il facture divers tarifs pour certaines sections de l'avion ou de l'hôtel. Exemple, première classe va coûter plus cher que l'entraîneur. Les chambres ont des suites penthouse qui coûtent plus cher. Assurez-vous que les salles seront disponibles et peuvent être planifiées.
#
# **Gestionnaire d'entreprise** - Créer une hiérarchie de classes - classe abstraite Employé et sous-classes HourlyEmployee, SalariedEmployee, Manager and Executive. Chaque paie est calculée différemment, la recherche un peu à ce sujet. Après avoir établi une hiérarchie d'employés, créez une classe d'entreprise qui vous permet de gérer les employés. Vous devriez être en mesure d'embaucher, de tirer et d'augmenter les employés.
#
# **Bank Account Manager** - Créer une classe appelée Account qui sera une classe abstraite pour trois autres classes appelées CheckingAccount, SavingsAccount et BusinessAccount. Gérer les crédits et les débits à partir de ces comptes grâce à un programme de style ATM.
#
# **Patient / Doctor Scheduler** - Créer une classe de patients et une classe de docteur. Demandez à un médecin qui peut traiter plusieurs patients et mettre en place un programme de planification où un médecin ne peut traiter que 16 patients pendant une journée de 8 heures de travail.
#
# **Recipe Créateur et gestionnaire** - Créer une classe de recette avec des ingrédients et les mettre dans un programme de gestion de recettes qui organise Dans des catégories comme les déserts, les plats principaux ou par des ingrédients comme le poulet, le boeuf, les soupes, les tartes, etc.
#
# **Galerie d'images** - Créez une classe abstraite d'image puis une classe qui en hérite pour chaque type d'image. Mettez-les dans un programme qui les affiche dans un format de style galerie pour la visualisation.
#
# **Zone de forme et classes de périmètre** - Créer une classe abstraite appelée Forme et hériter de lui d'autres formes comme le diamant, le rectangle, le cercle, le triangle, etc Ensuite, La zone et la fonctionnalité de périmètre pour gérer chaque type de forme.
#
# **Shop Flower Commander Pour aller** - Créer une application de magasin de fleurs qui traite des objets de fleurs et d'utiliser ces objets de fleurs dans un objet bouquet qui peut ensuite être vendu. Gardez une trace du nombre d'objets et quand vous aurez peut-être besoin de commander more.
#
# **Family Tree Creator** - Créer une classe appelée Personne qui aura un nom, quand ils sont nés et quand (et si) ils sont morts. Permettre à l'utilisateur de créer ces classes Person et de les mettre dans une structure arborescente. Imprimez l'arbre à l'écran.

# %% [markdown]
# ## Threading
#
# **Create Une barre de progression pour les téléchargements** - Créez une barre de progression pour les applications qui peuvent suivre un téléchargement en cours. La barre de progression sera sur un thread séparé et communiquera avec le thread principal en utilisant des délégués.
#
# **Thumbnail Creator** - Traitement d'image peut prendre un peu de temps pour certaines transformations. Surtout si l'image est grande. Créer un programme d'image qui peut prendre des centaines d'images et les convertit à une taille spécifiée dans le fil d'arrière-plan pendant que vous faites d'autres choses. Pour ajouter de la complexité, avoir un thread de traitement de redimensionnement, ont un autre renommage en masse de vignettes, etc

# %% [markdown]
# ## Web
#
# **Page Scraper** - Créer une application qui se connecte à un site et retire tous les liens, ou des images, et les enregistre dans une liste. Facultatif: Organisez le contenu indexé et ne permettez pas les doublons. Demandez-lui de mettre les résultats dans un fichier d'index facile à rechercher.
#
# **Online White Board** - Créez une application qui vous permet de dessiner des photos, d'écrire des notes et d'utiliser diverses couleurs pour étoffer les idées de projets. Facultatif: Ajouter fonctionnalité pour inviter des amis à collaborer sur un tableau blanc en ligne.
#
# **Obtenir le temps atomique de l'horloge Internet** - Ce programme obtiendra le temps atomique vrai d'une horloge atomique sur l'Internet. Utilisez l'une des horloges atomiques retournées par une simple recherche Google.
#
# **Recherchez la météo actuelle** - Obtenez la météo actuelle pour un code postal / code postal donné. Facultatif: Essayez de localiser l'utilisateur automatiquement.
#
# **Saisie et action automatique programmées** - Créez une application qui se connecte à un site donné selon une planification et appelle une certaine action puis se déconnecte. Cela peut être utile pour la vérification du courrier Web, l'affichage de contenu régulier, ou d'obtenir des informations pour d'autres applications et de les enregistrer sur votre ordinateur.
#
# **E-Card Generator** - Créer un site qui permet aux gens de générer leur propre petite e-cartes et les envoyer à d'autres gens. N'utilisez pas Flash. Utilisez une bibliothèque d'images et peut-être des devises ou des citations perspicaces.
#
# **Système e gestion de contenu** - Créer un système de gestion de contenu (CMS) comme Joomla, Drupal, PHP Nuke, etc Commencer petit. Facultatif: Permettre l'ajout de modules / addons.
#
# **Web Board (Forum)** - Créez un forum pour vous et vos amis pour publier, administrer et partager des idées et des pensées.
#
# **CAPTCHA Maker** - Voir jamais ces images avec des lettres un nombre lorsque vous vous inscrivez pour Un service et vous demande alors d'entrer ce que vous voyez? Il empêche les robots Web de s'inscrire automatiquement et de spammer. Essayez de créer un vous-même pour les formulaires en ligne.
#
# ## Files
#
# **Quiz Maker** - Faire une demande qui prend diverses questions à partir d'un fichier, choisi au hasard, et met en place un quiz pour les étudiants. Chaque quiz peut être différent et lit une clé pour classer les quiz.
#
# **Utilitaire de fichiers Excel Excel / CSV** - Lit un fichier d'enregistrements, les trie et les écrit dans le fichier. Permettre à l'utilisateur de choisir le style de tri et le tri différents basés sur un champ particulier.
#
# **Créer Zip File Maker** - L'utilisateur entre différents fichiers à partir de différents répertoires et le programme les met sous forme de zip dans un fichier zip. Facultatif: Appliquer la compression réelle aux fichiers. Commencez avec Huffman Algorithm.
#
# **PDF Generator** - Une application qui peut lire dans un fichier texte, un fichier html ou un autre fichier et génère un fichier PDF hors de lui. Idéal pour un service basé sur le Web où l'utilisateur télécharge le fichier et le programme renvoie un fichier PDF du fichier. Facultatif: Déployer sur GAE ou Heroku si possible.
#
# **Mp3 Tagger** - Modifier et ajouter des tags ID3v1 aux fichiers MP3. Voir si vous pouvez également ajouter dans l'art de l'album dans l'en-tête du fichier MP3 ainsi que d'autres tags ID3v2.
#
# **Code Snippet Manager** - Un autre programme utilitaire qui permet aux codeurs de mettre en fonctions, classes ou autres tidbits à enregistrer pour une utilisation ultérieure. Organisé par le type d'extrait ou de langage, le codeur peut rapidement rechercher le code.
#
# ## Bases de données
#
# **SQL Query Analyzer** - Un utilitaire qui permet à un utilisateur de saisir une requête et de l'exécuter sur une base de données locale et de chercher des moyens de le rendre plus efficace.
#
# **Remote SQL Tool** - Utilitaire qui peut exécuter des requêtes sur des serveurs distants à partir de votre ordinateur local via Internet. Il doit prendre un hôte distant, un nom d'utilisateur et un mot de passe, exécuter la requête et retourner les résultats.
#
# **Générateur de rapports** - Créer un utilitaire qui génère un rapport basé sur certaines tables dans une base de données. Génère des rapports de ventes basés sur les tables de détails de commande / commande ou résume les jours d'activité de la base de données courante.
#
# **Planificateur d'événements et calendrier** - Créez une application qui permet à l'utilisateur d'entrer une date et une heure d'événement, Sur un calendrier. L'utilisateur peut ensuite parcourir le calendrier ou rechercher des événements spécifiques dans le calendrier. Facultatif: Permettre à l'application de créer des événements de réapparition qui se reproduisent chaque jour, semaine, mois, année, etc.
#
# **Tracker Buddy** - Rédigez une application qui conserve la trace du budget d'un ménage. L'utilisateur peut ajouter les dépenses, le revenu et les coûts récurrents pour savoir combien ils sont d'épargne ou de perdre sur une période de temps. Facultatif: Permettre à l'utilisateur de spécifier une plage de dates et de voir le flux net d'argent dans et hors du budget de la maison pour cette période de temps.
#
# **TV Show Tracker** - Vous avez un spectacle préféré que vous ne voulez pas manquer? Vous n'avez pas de PVR ou voulez être en mesure de trouver le spectacle pour ensuite PVR il plus tard? Créez une application qui peut rechercher dans divers sites de TV Guide en ligne, localiser les émissions / périodes / canaux et les ajouter à une application de base de données. La base de données / site Web peut alors vous envoyer des rappels d'email qu'un spectacle est sur le point de commencer et quel canal il sera sur.
#
# **Travel Planner System** - Faites un système qui permet aux utilisateurs de mettre en place leur propre petit itinéraire de voyage et de garder une trace de la compagnie aérienne / Les arrangements d'hôtel, les points d'intérêt, le budget et l'horaire.
#
# ## Graphiques et Multimedia
#
# **Slide Show** - Faire une application qui montre diverses images dans un format de diaporama. Facultatif: Essayez d'ajouter des effets tels que Fade In / Out, star wipe et stores transitions.
#
# **Stream Video from Online** - Essayez de créer votre propre lecteur vidéo streaming en ligne.Mp3 Player - Un programme simple pour jouer vos fichiers musicaux préférés. Ajouter des fonctionnalités que vous pensez sont manquants à partir de votre lecteur de musique préféré.
#
# **Watermarking Application** - Certaines photos que vous voulez protégé par le droit d'auteur? Ajoutez votre propre logo ou texte légèrement à travers l'arrière-plan de sorte que personne ne peut simplement voler vos graphiques hors de votre emplacement. Créez un programme qui ajoutera ce filigrane à l'image. Facultatif: Utilisez threading pour traiter plusieurs images simultanément.
#
# **Graphiques de tour** - C'est un projet commun où vous créez un plancher de 20 x 20 carrés. En utilisant diverses commandes, vous dites à une tortue de tracer une ligne sur le sol. Vous avez aller de l'avant, à gauche ou à droite, l'ascenseur ou le stylo de baisse etc Faites une recherche en ligne pour "Turtle Graphics" pour plus d'informations. Facultatif: Permet au programme de lire dans la liste des commandes d'un fichier.
#
# **GIF Creator** -  Un programme qui regroupe plusieurs images (PNGs, JPGs, TIFFs) pour faire un GIF en douceur qui peut être exporté. Facultatif: Faire le programme de convertir les petits fichiers vidéo en GIF aussi.
#
# ## Securité
#
# **Chiffement César** - Mettre en œuvre un chiffrement César, codant et décodant. La clé est un entier de 1 à 25. Ce chiffre permet de faire tourner les lettres de l'alphabet (A à Z). L'encodage remplace chaque lettre par la 1ère à la 25ème lettre suivante dans l'alphabet (enveloppe Z à A). Donc la clé 2 chiffre "HI" à "JK", mais la clé 20 crypte "HI" à "BC". Ce simple "chiffre de substitution monoalphabétique" n'offre presque aucune sécurité, car un attaquant qui a le message encodé peut soit utiliser l'analyse de fréquence pour deviner la clé, soit essayer toutes les 25 clés
