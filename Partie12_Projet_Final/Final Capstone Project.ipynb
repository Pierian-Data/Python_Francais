# %% [markdown]
# # Projet Final
#
# Veuillez vous référer au dossier [**Projet Final**] (http://nbviewer.jupyter.org/github/jmportilla/Python_Francais/Final%20Capstone%20Projects) pour obtenir toutes les informations sur le projet final et les solutions possibles!
